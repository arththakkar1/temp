# %% [markdown]
# ## Q1. Simple Output

# %%
print("Arth Thakkar")
print("Ahmedabad")
print("Welcome to Data Analytics")
# Out:
# Arth Thakkar
# Ahmedabad
# Welcome to Data Analytics

# %% [markdown]
# ## Q2. User Input

# %%
Name=input("Enter your name:")
Age=int(input("Enter your age:"))
print(f"My name is {Name} and I am {Age} years old")
# Out:
# My name is Arth and I am 20 years old

# %% [markdown]
# ## Q3. Multiple Inputs

# %%
Name=input("Enter your name:")
Course=input("Enter your course:")
Fees=int(input("Enter your fees:"))
print(f"My name is {Name} and I am doing {Course} at fees of {Fees}")
# Out:
# My name is Arth and I am doing Data Analytics at fees of 15000

# %% [markdown]
# ## Q4. Variable Assignment

# %%
student_name = "Arth"
marks = 85
passed = True

print("Student Name:", student_name)
print("Marks:", marks)
print("Passed:", passed)
# Out:
# Student Name: Arth
# Marks: 85
# Passed: True

# %% [markdown]
# ## Q5. Multiple Assignment

# %%
student_name = "Arth"
marks = 85
passed = True

print(f"My name is {student_name} and i got {marks} so i am {passed}")
# Out:
# My name is Arth and i got 85 so i am True

# %% [markdown]
# ## Q6. Swap Two Variables

# %%
a=10
b=20
a,b=b,a
print(f"a:{a}\nb:{b}")
# Out:
# a:20
# b:10

# %% [markdown]
# ## Q7. Identify Data Types

# %%
student_name = "Arth"
marks = 85
math_marks=80.5
passed = True

print(type(student_name))
print(type(marks))
print(type(math_marks))
print(type(passed))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# ## Q8. Type Conversion

# %%
Age=input("Enter your age:")
Salary=input("Enter your salary")

Age=int(Age)
Salary=float(Salary)

print(type(Age))
print(type(Salary))
# Out:
# <class 'int'>
# <class 'float'>

# %% [markdown]
# ## Q9. Mixed Operations

# %%
x = 10
y = 5.5
z = x+y

print(z)
print(type(z))
# Out:
# 15.5
# <class 'float'>

# %% [markdown]
# ## Q10. Arithmetic Operations

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print("Addition:", num1 + num2)
print("Subtraction:", num1 - num2)
print("Multiplication:", num1 * num2)

if num2 != 0:
    print("Division:", num1 / num2)
    print("Modulus:", num1 % num2)
else:
    print("Division and Modulus not possible (division by zero)")
# Out:
# Addition: 30.0
# Subtraction: -10.0
# Multiplication: 200.0
# Division: 0.5
# Modulus: 10.0

# %% [markdown]
# ## Q11. Comparison Operators

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

if num1 > num2:
    print("Greater number:", num1)
    print("Smaller number:", num2)
elif num2 > num1:
    print("Greater number:", num2)
    print("Smaller number:", num1)
else:
    print("Both numbers are equal")
# Out:
# Greater number: 20.0
# Smaller number: 10.0

# %% [markdown]
# ## Q12. Logical Operators

# %%
a = input("Enter first boolean (True/False): ") == "True"
b = input("Enter second boolean (True/False): ") == "True"

print("AND:", a and b)
print("OR:", a or b)
print("NOT of first:", not a)
print("NOT of second:", not b)
# Out:
# AND: False
# OR: True
# NOT of first: False
# NOT of second: True

# %% [markdown]
# ## Q13. Assignment Operators

# %%
num = int(input("Enter a number: "))

num += 5
print("After += 5:", num)

num -= 2
print("After -= 2:", num)

num *= 3
print("After *= 3:", num)
# Out:
# After += 5: 15
# After -= 2: 13
# After *= 3: 39

# %% [markdown]
# ## Q14. Membership Operator

# %%
string = input("Enter string: ")
char = input("Enter character: ")

if char in string:
    print(True)
else:
    print(False)
# Out:
# True

# %% [markdown]
# ## Q15. Identity Operator

# %%
a=10
b=20

print(a is b)
print(a is not b)
# Out:
# False
# True

# %% [markdown]
# ## Q16. Student Details Program

# %%
Name=input("Enter your name:")
Age=int(input("Enter your age:"))
Marks=float(input("Enter your marks:"))
print(f"Student {Name} scored {Marks} marks and is {Age} years old")
# Out:
# Student Arth scored 100.0 marks and is 20 years old

# %% [markdown]
# ## Q17. Simple Interest Calculator

# %%
Principal=int(input("Enter your principal:"))
Rate=int(input("Enter your rate:"))
Time=int(input("Enter your time:"))

SI = (Principal * Rate * Time) / 100

print(f"Interest:{SI}")
# Out:
# Interest:96.0

# %% [markdown]
# ## Q18. Salary Calculator

# %%
basic_salary = float(input("Enter Basic Salary: "))

hra = basic_salary * 0.20
da = basic_salary * 0.10

total_salary = basic_salary + hra + da

print("HRA:", hra)
print("DA:", da)
print("Total Salary:", total_salary)
# Out:
# HRA: 3000.0
# DA: 1500.0
# Total Salary: 19500.0

# %% [markdown]
# ## Q19. Even or Odd

# %%
def check(num):
    if num%2==0:
        print("Even")
    else:
        print("Odd")

Num=int(input("Enter Number:"))
check(Num)
# Out:
# Odd

# %% [markdown]
# ## Q20. Largest of Two Numbers

# %%
def Largest(N1,N2):
    print(max(N1,N2))

N1=int(input("Enter number 1:"))
N2=int(input("Enter number 2:"))

Largest(N1,N2)
# Out:
# 100
