# %% [markdown]
# ## Using Open Weather Map API, generate current air pollution data for Delhi and extract detail of “nh3”
# lat=23.05
# lon=14.05
# ## API call request:
# # Example of the API response:
# {
# "coord":[
# 50,
# 50
# ],
# "list":[
# {
# "dt":1605182400,
# "main":{
# "aqi":500
# },
# "components":{
# "co":201.94053649902344,
# "no":0.01877197064459324,
# "no2":0.7711350917816162,
# "o3":68.66455078125,
# "so2":0.6407499313354492,
# "pm2_5":0.5,
# "pm10":0.540438711643219,
# "nh3":0.12369127571582794
# }
# }
# }

# %%
import requests

API_KEY="a2d8a5383655bf8e313435d0b68ae065"
lat=23.05
lon=14.05

Link=f"http://api.openweathermap.org/data/2.5/air_pollution?lat={lat}&lon={lon}&appid={API_KEY}"

data=requests.get(Link)

res=data.json()

print(res["list"][0]["components"]["nh3"])
print(res)
# Out:
# 0
# {'coord': {'lon': 14.05, 'lat': 23.05}, 'list': [{'main': {'aqi': 4}, 'components': {'co': 76.05, 'no': 0.01, 'no2': 0.04, 'o3': 60.26, 'so2': 0.03, 'pm2_5': 22.53, 'pm10': 118.08, 'nh3': 0}, 'dt': 1781608256}]}
